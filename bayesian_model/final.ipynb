# %% [markdown]
# # Online maths education modelling

# %% [markdown]
# > Note
# > We can copy all of these files into an rmd file later

# %% [markdown]
# ## Introduction
#
# ### Raison d'etre
#
# Mathematical education modelling is a vital task today. For two reasons:
# We are living in an increasingly technical world where the demands of the workforce are increasingly specialised in stem related subjects; a solid maths background lies at the core excelling in these areas not just on the individual level but also the governmental societal planning level.
# Secondly with the rising inequality, in many developing nations as well as developed nations, maths education is a great equaliser as it enables many students to achieve better lives in than their parents. Furthermore in the resource constrained areas with poor function of schools online maths education has the ability to aid teachers in providing a higher standard of learning for students.
#
# An important question is, "Why then are we modelling the mathematics abilities of students rather than simply just giving them more problems? Why is this practice of modeling important?" It is important because for students learning mathematics one on the most important things is knowing what you do not yet know. That is knowing your abilities as this enables targeted practice for students in learning what they do not yet know. For governments and teachers the same interest is there. We perform tests to try understand where a class is academically and adjust the syllabus accordingly, focusing on weak spots and reclarifying what is neccessary. Governments may recognise bias in the education system and seek to correct certain statas of the population in particular geographies performing worse than others. Furthermore governments are able to get feedback on particalur interventions to see if they are actually working. Thus measuring students abilities enables resource planning on behalf of students, educators and governments.

# %% [markdown]
# ### Rivet / Focus
#
# The central question of this paper is can we work out the abilities of students accurately. We will use callibration as a measure for this.

# %% [markdown]
# ## Data Exploration
#
#
# In this paper we focus on analysing the EEDI database. This database was

# %% [markdown]
# ## Model
#
#
# ### Key Assumptions
#
#
#
#
# ### Mathematics

# %% [markdown]
# ## Analysis
